# %%
import pandas as pd

df1 = pd.read_csv('/content/bomAll_nan포함.csv')
df1
# Out:
# <ipython-input-20-fe8da3e4608c>:3: DtypeWarning: Columns (3,4,5,7,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv('/content/bomAll_nan포함.csv')
#        Unnamed: 0       작가명      작가ID 댓글총갯수 댓글총페이지 게시물인덱스  \
# 0             0.0        운석  WofGHOST    20    128    0.0
# 1             1.0        운석  WofGHOST    20    128    1.0
# 2             2.0        운석  WofGHOST    20    128    2.0
# 3             3.0        운석  WofGHOST    20    128    3.0
# 4             4.0        운석  WofGHOST    20    128    4.0
# ...           ...       ...       ...   ...    ...    ...
# 89491     35635.0  Soudasui  1_second    20      5    NaN
# 89492     35636.0  Soudasui  1_second    20      5    NaN
# 89493     35637.0  Soudasui  1_second     2      5    NaN
# 89494     35638.0  Soudasui  1_second     2      5    NaN
# 89495     35639.0  Soudasui  1_second     2      5    NaN
#
#                      댓글쓴날짜     댓글의idx    작품명 작품회차       댓글자명  \
# 0      2022-12-11 22:04:03  1066439.0  유령의 창   9화        그랬댕
# 1      2022-11-16 21:34:26  1037290.0  유령의 창   6화  봄툰러685cef
# 2      2022-11-27 22:13:02  1049813.0  유령의 창   7화   현실도pizza
# 3      2022-11-16 22:05:50  1037388.0  유령의 창   6화       샤브리나
# 4      2022-11-16 22:14:44  1037483.0  유령의 창   5화  봄툰러271bb9
# ...                    ...        ...    ...  ...        ...
# 89491                  NaN        NaN    NaN  NaN        NaN
# 89492                  NaN        NaN    NaN  NaN        NaN
# 89493                  NaN        NaN    NaN  NaN        NaN
# 89494                  NaN        NaN    NaN  NaN        NaN
# 89495                  NaN        NaN    NaN  NaN        NaN
#
#                                                       댓글  좋아요횟수
# 0                 아니.... 상상도 못한 방법으로 회피하셔가지고 저도 놀랐어요...   699.0
# 1      아무리 생각해도 어릴적에 너무나도 매력적인 남성과의 접촉이,,,, 그의 성적 취형을...  457.0
# 2                          하...계란야무지게얹은미니토스트아이팟케이스쓰는공어때,  444.0
# 3                                        그럼 아저씨가 평생 책임져요  436.0
# 4                          정말 죄송한데 딱 한번만 실수로 벽에 끼이셨으면..!  369.0
# ...                                                  ...    ...
# 89491                                                NaN    NaN
# 89492                                                NaN    NaN
# 89493                                                NaN    NaN
# 89494                                                NaN    NaN
# 89495                                                NaN    NaN
#
# [89496 rows x 13 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89496 entries, 0 to 89495
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  89489 non-null  float64
#  1   작가명         89496 non-null  object
#  2   작가ID        89496 non-null  object
#  3   댓글총갯수       89496 non-null  object
#  4   댓글총페이지      89496 non-null  object
#  5   게시물인덱스      85146 non-null  object
#  6   댓글쓴날짜       85146 non-null  object
#  7   댓글의idx      85146 non-null  object
#  8   작품명         85146 non-null  object
#  9   작품회차        82156 non-null  object
#  10  댓글자명        85138 non-null  object
#  11  댓글          73335 non-null  object
#  12  좋아요횟수       85146 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 8.9+ MB

# %%
df1.isna().sum()
# Out:
# Unnamed: 0        7
# 작가명               0
# 작가ID              0
# 댓글총갯수             0
# 댓글총페이지            0
# 게시물인덱스         4350
# 댓글쓴날짜          4350
# 댓글의idx         4350
# 작품명            4350
# 작품회차           7340
# 댓글자명           4358
# 댓글            16161
# 좋아요횟수          4350
# dtype: int64

# %%
df1.isnull().sum() # 결측치
# Out:
# Unnamed: 0        7
# 작가명               0
# 작가ID              0
# 댓글총갯수             0
# 댓글총페이지            0
# 게시물인덱스         4350
# 댓글쓴날짜          4350
# 댓글의idx         4350
# 작품명            4350
# 작품회차           7340
# 댓글자명           4358
# 댓글            16161
# 좋아요횟수          4350
# dtype: int64

# %%
df1 = df1.dropna(subset = ['댓글']) # 결측치 있는 댓글 행 제거

# %%
df1['댓글']
# Out:
# 0                   아니.... 상상도 못한 방법으로 회피하셔가지고 저도 놀랐어요...
# 1        아무리 생각해도 어릴적에 너무나도 매력적인 남성과의 접촉이,,,, 그의 성적 취형을...
# 2                            하...계란야무지게얹은미니토스트아이팟케이스쓰는공어때,
# 3                                          그럼 아저씨가 평생 책임져요
# 4                            정말 죄송한데 딱 한번만 실수로 벽에 끼이셨으면..!
#                                ...
# 87777                                                   아.
# 87778                                             정말  펜이에요
# 87779                                          짱구는 여기서 눕는다
# 87780         봄툰은 연재빠른데 카카오페이지는 진짜 안올라오네ㅠㅠㅠ... 이용권 다 바꿔놨는데
# 87781                               오~~~♡♡근데 무료가 더있었으면....
# Name: 댓글, Length: 73335, dtype: object

# %%
df1.isnull().sum() # 결측치
# Out:
# Unnamed: 0       7
# 작가명              0
# 작가ID             0
# 댓글총갯수            0
# 댓글총페이지           0
# 게시물인덱스           0
# 댓글쓴날짜            0
# 댓글의idx           0
# 작품명              0
# 작품회차          2348
# 댓글자명             4
# 댓글               0
# 좋아요횟수            0
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 73335 entries, 0 to 87781
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  73328 non-null  float64
#  1   작가명         73335 non-null  object
#  2   작가ID        73335 non-null  object
#  3   댓글총갯수       73335 non-null  object
#  4   댓글총페이지      73335 non-null  object
#  5   게시물인덱스      73335 non-null  object
#  6   댓글쓴날짜       73335 non-null  object
#  7   댓글의idx      73335 non-null  object
#  8   작품명         73335 non-null  object
#  9   작품회차        70987 non-null  object
#  10  댓글자명        73331 non-null  object
#  11  댓글          73335 non-null  object
#  12  좋아요횟수       73335 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 7.8+ MB

# %%
df1
# Out:
#        Unnamed: 0        작가명      작가ID 댓글총갯수 댓글총페이지 게시물인덱스  \
# 0             0.0         운석  WofGHOST    20    128    0.0
# 1             1.0         운석  WofGHOST    20    128    1.0
# 2             2.0         운석  WofGHOST    20    128    2.0
# 3             3.0         운석  WofGHOST    20    128    3.0
# 4             4.0         운석  WofGHOST    20    128    4.0
# ...           ...        ...       ...   ...    ...    ...
# 87777     33921.0  samk, 푸죠킹   PAYBACK    20   1685   16.0
# 87778     33922.0  samk, 푸죠킹   PAYBACK    20   1685   17.0
# 87779     33923.0  samk, 푸죠킹   PAYBACK    20   1685   18.0
# 87780     33924.0  samk, 푸죠킹   PAYBACK    20   1685   19.0
# 87781     33925.0  samk, 푸죠킹   PAYBACK    20   1685    0.0
#
#                      댓글쓴날짜     댓글의idx          작품명 작품회차       댓글자명  \
# 0      2022-12-11 22:04:03  1066439.0        유령의 창   9화        그랬댕
# 1      2022-11-16 21:34:26  1037290.0        유령의 창   6화  봄툰러685cef
# 2      2022-11-27 22:13:02  1049813.0        유령의 창   7화   현실도pizza
# 3      2022-11-16 22:05:50  1037388.0        유령의 창   6화       샤브리나
# 4      2022-11-16 22:14:44  1037483.0        유령의 창   5화  봄툰러271bb9
# ...                    ...        ...          ...  ...        ...
# 87777  2019-08-22 12:49:58   102714.0  키스까지 앞으로 1초  제3화        ???
# 87778  2019-06-23 13:49:29    86694.0  키스까지 앞으로 1초  제1화  봄툰러8d29b9
# 87779  2019-04-29 18:29:11    74733.0  키스까지 앞으로 1초  NaN         짱구
# 87780  2019-02-03 03:34:36    56521.0  키스까지 앞으로 1초  NaN     엘로우라이트
# 87781  2019-01-20 19:11:54    53861.0  키스까지 앞으로 1초  제1화  봄툰러d56995
#
#                                                       댓글  좋아요횟수
# 0                 아니.... 상상도 못한 방법으로 회피하셔가지고 저도 놀랐어요...   699.0
# 1      아무리 생각해도 어릴적에 너무나도 매력적인 남성과의 접촉이,,,, 그의 성적 취형을...  457.0
# 2                          하...계란야무지게얹은미니토스트아이팟케이스쓰는공어때,  444.0
# 3                                        그럼 아저씨가 평생 책임져요  436.0
# 4                          정말 죄송한데 딱 한번만 실수로 벽에 끼이셨으면..!  369.0
# ...                                                  ...    ...
# 87777                                                 아.    0.0
# 87778                                           정말  펜이에요    0.0
# 87779                                        짱구는 여기서 눕는다    0.0
# 87780       봄툰은 연재빠른데 카카오페이지는 진짜 안올라오네ㅠㅠㅠ... 이용권 다 바꿔놨는데    0.0
# 87781                             오~~~♡♡근데 무료가 더있었으면....    0.0
#
# [73335 rows x 13 columns]

# %%
df1.to_csv("AllReviewMVDrop_BUM.csv", index = False)

# %%
df1.to_excel("AllReviewMVDrop_BUM.xlsx", index = False)
